# %%
from pandas import read_csv
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = read_csv("House-votes-data.TXT", header=None)
dataset = dataset.replace("?", np.NaN)

# %%
sns.set_style('whitegrid')
sns.countplot(x=16,data=dataset)
# Out:
# <AxesSubplot:xlabel='16', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=0,data=dataset)
# Out:
# <AxesSubplot:xlabel='0', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=1,data=dataset)
# Out:
# <AxesSubplot:xlabel='1', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=2,data=dataset)
# Out:
# <AxesSubplot:xlabel='2', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=3,data=dataset)
# Out:
# <AxesSubplot:xlabel='3', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=4,data=dataset)
# Out:
# <AxesSubplot:xlabel='4', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=5,data=dataset)
# Out:
# <AxesSubplot:xlabel='5', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=6,data=dataset)
# Out:
# <AxesSubplot:xlabel='6', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=7,data=dataset)
# Out:
# <AxesSubplot:xlabel='7', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=8,data=dataset)
# Out:
# <AxesSubplot:xlabel='8', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=9,data=dataset)
# Out:
# <AxesSubplot:xlabel='9', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=10,data=dataset)
# Out:
# <AxesSubplot:xlabel='10', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=11,data=dataset)
# Out:
# <AxesSubplot:xlabel='11', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=12,data=dataset)
# Out:
# <AxesSubplot:xlabel='12', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=13,data=dataset)
# Out:
# <AxesSubplot:xlabel='13', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=14,data=dataset)
# Out:
# <AxesSubplot:xlabel='14', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x=15,data=dataset)
# Out:
# <AxesSubplot:xlabel='15', ylabel='count'>
