# %%
from pandas import read_csv
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = read_csv("House-votes-data-modified.TXT")
dataset = dataset.replace("?", np.NaN)
dataset.head()
# Out:
#   handicapped-infants water-project-cost-sharing  \
# 0                   n                          y
# 1                   n                          y
# 2                 NaN                          y
# 3                   n                          y
# 4                   y                          y
#
#   adoption-of-the-budget-resolution physician-fee-freeze el-salvador-aid  \
# 0                                 n                    y               y
# 1                                 n                    y               y
# 2                                 y                  NaN               y
# 3                                 y                    n             NaN
# 4                                 y                    n               y
#
#   religious-groups-in-schools anti-satellite-test-ban  \
# 0                           y                       n
# 1                           y                       n
# 2                           y                       n
# 3                           y                       n
# 4                           y                       n
#
#   aid-to-nicaraguan-contras mx-missile immigration  \
# 0                         n          n           y
# 1                         n          n           n
# 2                         n          n           n
# 3                         n          n           n
# 4                         n          n           n
#
#   synfuels-corporation-cutback education-spending superfund-right-to-sue  \
# 0                          NaN                  y                      y
# 1                            n                  y                      y
# 2                            y                  n                      y
# 3                            y                  n                      y
# 4                            y                NaN                      y
#
#   crime duty-free-exports export-administration-act-south-africa   ClassName
# 0     y                 n                                      y  republican
# 1     y                 n                                    NaN  republican
# 2     y                 n                                      n    democrat
# 3     n                 n                                      y    democrat
# 4     y                 y                                      y    democrat

# %%
sns.set(font_scale=1.2)
fig, ax = plt.subplots(figsize=(12,7)) 
sns.heatmap(dataset.isnull(),yticklabels=False,cbar=False, cmap = 'viridis', ax=ax)
plt.savefig('./images/missing-datapoints-in-the-dataset.png', dpi=400, bbox_inches='tight')

# %%
sns.set_style('whitegrid')
sns.countplot(x='ClassName',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/ClassName.png', dpi=300, bbox_inches='tight')

# %%
sns.set_style('whitegrid')
sns.countplot(x='handicapped-infants',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/handicapped-infants.png', dpi=300, bbox_inches='tight')

# %%
sns.set_style('whitegrid')
sns.countplot(x='adoption-of-the-budget-resolution',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/adoption-of-the-budget-resolution.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='handicapped-infants',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/adoption-of-the-budget-resolution.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(9,6))
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='water-project-cost-sharing',hue='ClassName',data=dataset,palette='rainbow', ax = ax)
plt.savefig('./images/water-project-cost-sharing.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='adoption-of-the-budget-resolution',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/adoption-of-the-budget-resolution.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='adoption-of-the-budget-resolution',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/adoption-of-the-budget-resolution.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='el-salvador-aid',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/el-salvador-aid.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(7,7))
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='religious-groups-in-schools',hue='ClassName',data=dataset,palette='rainbow', ax = ax)
plt.savefig('./images/religious-groups-in-schools.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='anti-satellite-test-ban',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/anti-satellite-test-ban.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='aid-to-nicaraguan-contras',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/aid-to-nicaraguan-contras.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='mx-missile',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/mx-missile.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(9,5))
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='immigration',hue='ClassName',data=dataset,palette='rainbow', ax=ax)
plt.savefig('./images/immigration.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(6,8))
sns.set(font_scale=1.1)
sns.set_style('whitegrid')
sns.countplot(x='synfuels-corporation-cutback',hue='ClassName',data=dataset,palette='rainbow', ax = ax)
plt.savefig('./images/synfuels-corporation-cutback.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='education-spending',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/education-spending.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='superfund-right-to-sue',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/superfund-right-to-sue.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='crime',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/crime.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='duty-free-exports',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/duty-free-exports.png', dpi=300, bbox_inches='tight')

# %%
sns.set(font_scale=1.4)
sns.set_style('whitegrid')
sns.countplot(x='export-administration-act-south-africa',hue='ClassName',data=dataset,palette='rainbow')
plt.savefig('./images/export-administration-act-south-africa.png', dpi=300, bbox_inches='tight')
